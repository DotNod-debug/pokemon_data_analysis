# %%
import pandas as pd

# %%
data = [100, 102, 104]
series = pd.Series(data, index = ['a','b','c'])
series.loc['c'] = 200   # iloc for int location and loc for location label
print(series[series<200])
# Out:
# a    100
# b    102
# dtype: int64

# %%
calories = {"Day 1": 1750, "Day 2": 530, "Day 3": 850} #no labeling of indexing required in dictionary
series = pd.Series(calories)
series
# Out:
# Day 1    1750
# Day 2     530
# Day 3     850
# dtype: int64

# %%
series.loc["Day 3"]
# Out:
# np.int64(1550)

# %%
series[series>=1000]
# Out:
# Day 1    1750
# Day 3    1550
# dtype: int64

# %%
data = {"Name":["Luffy", "Zoro", "Nami"],
        "Bounty": [5000, 4000, 3000]
       }

df = pd.DataFrame(data, index = ['Pirate 1', 'Pirate 2', 'Pirate 3'])
print(df)
# Out:
#            Name  Bounty
# Pirate 1  Luffy    5000
# Pirate 2   Zoro    4000
# Pirate 3   Nami    3000

# %%
df.loc['Pirate 2']
# Out:
# Name      Zoro
# Bounty    4000
# Name: Pirate 2, dtype: object

# %%
df.iloc[2]
# Out:
# Name      Nami
# Bounty    3000
# Name: Pirate 3, dtype: object

# %%
df
# Out:
#            Name  Bounty
# Pirate 1  Luffy    5000
# Pirate 2   Zoro    4000
# Pirate 3   Nami    3000

# %%
#new column
df["Title"] = ["Captain", "Swordsman", "Navigator"]
df
# Out:
#            Name  Bounty      Title
# Pirate 1  Luffy    5000    Captain
# Pirate 2   Zoro    4000  Swordsman
# Pirate 3   Nami    3000  Navigator

# %%
#adds new row
new_rows = pd.DataFrame([{"Name": "Sanji", "Bounty": 4000, "Title": "Cook"}], index = ['Pirate 4'])
df = pd.concat([df,new_rows])
df
# Out:
#            Name  Bounty      Title
# Pirate 1  Luffy    5000    Captain
# Pirate 2   Zoro    4000  Swordsman
# Pirate 3   Nami    3000  Navigator
# 0         Sanji    4000       Cook
# 0         Sanji    4000       Cook
# 0         Sanji    4000       Cook
# Pirate 4  Sanji    4000       Cook

# %%
df = df.drop(0) #drops rows with index 0, 0 is the index name
df
# Out:
#            Name  Bounty      Title
# Pirate 1  Luffy    5000    Captain
# Pirate 2   Zoro    4000  Swordsman
# Pirate 3   Nami    3000  Navigator
# Pirate 4  Sanji    4000       Cook

# %%
df = pd.read_csv("Pokemon.csv", index_col = "Name")
df
# Out:
#              No    Type1   Type2  Height  Weight  Legendary
# Name
# Bulbasaur     1    Grass  Poison     0.7     6.9          0
# Ivysaur       2    Grass  Poison     1.0    13.0          0
# Venusaur      3    Grass  Poison     2.0   100.0          0
# Charmander    4     Fire     NaN     0.6     8.5          0
# Charmeleon    5     Fire     NaN     1.1    19.0          0
# ...         ...      ...     ...     ...     ...        ...
# Moltres     146     Fire  Flying     2.0    60.0          1
# Dratini     147   Dragon     NaN     1.8     3.3          0
# Dragonair   148   Dragon     NaN     4.0    16.5          0
# Dragonite   149   Dragon  Flying     2.2   210.0          0
# Mewtwo      150  Psychic     NaN     2.0   122.0          1
#
# [150 rows x 6 columns]

# %%
# df.to_string() #provides entire info
# Out:
# "      No        Name     Type1     Type2  Height  Weight  Legendary\n0      1   Bulbasaur     Grass    Poison     0.7     6.9          0\n1      2     Ivysaur     Grass    Poison     1.0    13.0          0\n2      3    Venusaur     Grass    Poison     2.0   100.0          0\n3      4  Charmander      Fire       NaN     0.6     8.5          0\n4      5  Charmeleon      Fire       NaN     1.1    19.0          0\n5      6   Charizard      Fire    Flying     1.7    90.5          0\n6      7    Squirtle     Water       NaN     0.5     9.0          0\n7      8   Wartortle     Water       NaN     1.0    22.5          0\n8      9   Blastoise     Water       NaN     1.6    85.5          0\n9     10    Caterpie       Bug       NaN     0.3     2.9          0\n10    11     Metapod       Bug       NaN     0.7     9.9          0\n11    12  Butterfree       Bug    Flying     1.1    32.0          0\n12    13      Weedle       Bug    Poison     0.3     3.2          0\n13    14      Kakuna       Bug 
# ...

# %%
#Selection by column
df["Name"]
# Out:
# 0       Bulbasaur
# 1         Ivysaur
# 2        Venusaur
# 3      Charmander
# 4      Charmeleon
#           ...
# 145       Moltres
# 146       Dratini
# 147     Dragonair
# 148     Dragonite
# 149        Mewtwo
# Name: Name, Length: 150, dtype: object

# %%
df[["Weight", "Height"]]
# Out:
#      Weight  Height
# 0       6.9     0.7
# 1      13.0     1.0
# 2     100.0     2.0
# 3       8.5     0.6
# 4      19.0     1.1
# ..      ...     ...
# 145    60.0     2.0
# 146     3.3     1.8
# 147    16.5     4.0
# 148   210.0     2.2
# 149   122.0     2.0
#
# [150 rows x 2 columns]

# %%
df[[]]#Selection by Rows
df
# Out:
#       No        Name    Type1   Type2  Height  Weight  Legendary
# 0      1   Bulbasaur    Grass  Poison     0.7     6.9          0
# 1      2     Ivysaur    Grass  Poison     1.0    13.0          0
# 2      3    Venusaur    Grass  Poison     2.0   100.0          0
# 3      4  Charmander     Fire     NaN     0.6     8.5          0
# 4      5  Charmeleon     Fire     NaN     1.1    19.0          0
# ..   ...         ...      ...     ...     ...     ...        ...
# 145  146     Moltres     Fire  Flying     2.0    60.0          1
# 146  147     Dratini   Dragon     NaN     1.8     3.3          0
# 147  148   Dragonair   Dragon     NaN     4.0    16.5          0
# 148  149   Dragonite   Dragon  Flying     2.2   210.0          0
# 149  150      Mewtwo  Psychic     NaN     2.0   122.0          1
#
# [150 rows x 7 columns]

# %%
df.loc[0]
# Out:
# No                   1
# Name         Bulbasaur
# Type1            Grass
# Type2           Poison
# Height             0.7
# Weight             6.9
# Legendary            0
# Name: 0, dtype: object

# %%
df
# Out:
#              No    Type1   Type2  Height  Weight  Legendary
# Name
# Bulbasaur     1    Grass  Poison     0.7     6.9          0
# Ivysaur       2    Grass  Poison     1.0    13.0          0
# Venusaur      3    Grass  Poison     2.0   100.0          0
# Charmander    4     Fire     NaN     0.6     8.5          0
# Charmeleon    5     Fire     NaN     1.1    19.0          0
# ...         ...      ...     ...     ...     ...        ...
# Moltres     146     Fire  Flying     2.0    60.0          1
# Dratini     147   Dragon     NaN     1.8     3.3          0
# Dragonair   148   Dragon     NaN     4.0    16.5          0
# Dragonite   149   Dragon  Flying     2.2   210.0          0
# Mewtwo      150  Psychic     NaN     2.0   122.0          1
#
# [150 rows x 6 columns]

# %%
df.loc["Charizard", ["Height", "Weight"]]
# Out:
# Height     1.7
# Weight    90.5
# Name: Charizard, dtype: object

# %%
df.iloc[0:16]
# Out:
#             No   Type1   Type2  Height  Weight  Legendary
# Name
# Bulbasaur    1   Grass  Poison     0.7     6.9          0
# Ivysaur      2   Grass  Poison     1.0    13.0          0
# Venusaur     3   Grass  Poison     2.0   100.0          0
# Charmander   4    Fire     NaN     0.6     8.5          0
# Charmeleon   5    Fire     NaN     1.1    19.0          0
# Charizard    6    Fire  Flying     1.7    90.5          0
# Squirtle     7   Water     NaN     0.5     9.0          0
# Wartortle    8   Water     NaN     1.0    22.5          0
# Blastoise    9   Water     NaN     1.6    85.5          0
# Caterpie    10     Bug     NaN     0.3     2.9          0
# Metapod     11     Bug     NaN     0.7     9.9          0
# Butterfree  12     Bug  Flying     1.1    32.0          0
# Weedle      13     Bug  Poison     0.3     3.2          0
# Kakuna      14     Bug  Poison     0.6    10.0          0
# Beedrill    15     Bug  Poison     1.0    29.5          0
# ...

# %%
df.iloc[0:16:2, 0:3]   #[row1:rown:jump, col1:coln]
# Out:
#             No  Type1   Type2
# Name
# Bulbasaur    1  Grass  Poison
# Venusaur     3  Grass  Poison
# Charmeleon   5   Fire     NaN
# Squirtle     7  Water     NaN
# Blastoise    9  Water     NaN
# Metapod     11    Bug     NaN
# Weedle      13    Bug  Poison
# Beedrill    15    Bug  Poison

# %%
pokemon = input("Enter a Pokemon name: ")
try:
    print(df.loc[pokemon])
except KeyError:
    print(f"{pokemon} not found")
# Out:
# Enter a Pokemon name:  ujhuih
# ujhuih not found

# %%
df
# Out:
#              No    Type1   Type2  Height  Weight  Legendary
# Name
# Bulbasaur     1    Grass  Poison     0.7     6.9          0
# Ivysaur       2    Grass  Poison     1.0    13.0          0
# Venusaur      3    Grass  Poison     2.0   100.0          0
# Charmander    4     Fire     NaN     0.6     8.5          0
# Charmeleon    5     Fire     NaN     1.1    19.0          0
# ...         ...      ...     ...     ...     ...        ...
# Moltres     146     Fire  Flying     2.0    60.0          1
# Dratini     147   Dragon     NaN     1.8     3.3          0
# Dragonair   148   Dragon     NaN     4.0    16.5          0
# Dragonite   149   Dragon  Flying     2.2   210.0          0
# Mewtwo      150  Psychic     NaN     2.0   122.0          1
#
# [150 rows x 6 columns]

# %%
df.mean(numeric_only=True)
# Out:
# No           75.500000
# Height        1.200000
# Weight       46.231333
# Legendary     0.026667
# dtype: float64

# %%
df.sum(numeric_only=True)
# Out:
# No           11325.0
# Height         180.0
# Weight        6934.7
# Legendary        4.0
# dtype: float64

# %%
df.max(numeric_only=True)
# Out:
# No           150.0
# Height         8.8
# Weight       460.0
# Legendary      1.0
# dtype: float64

# %%
df.count()
# Out:
# No           150
# Type1        150
# Type2         67
# Height       150
# Weight       150
# Legendary    150
# dtype: int64

# %%
# mean(), min(), max(),sum(), count() are aggregate functions applicable to whole database


#Single Column
df["Height"].mean()
# Out:
# np.float64(1.2)

# %%
df["Height"].sum()
# Out:
# np.float64(180.0)

# %%
df["Height"].min()
# Out:
# np.float64(0.2)

# %%
group = df.groupby("Type1")
group

# %%
group.mean(numeric_only = True)
# Out:
#                   No    Height     Weight  Legendary
# Type1
# Bug        42.916667  0.900000  22.991667   0.000000
# Dragon    148.000000  2.666667  76.600000   0.000000
# Electric   91.111111  0.855556  31.788889   0.111111
# Fairy      35.500000  0.950000  23.750000   0.000000
# Fighting   75.285714  1.185714  54.285714   0.000000
# Fire       64.166667  1.216667  48.025000   0.083333
# Ghost      93.000000  1.466667  13.566667   0.000000
# Grass      55.583333  1.083333  27.991667   0.000000
# Ground     73.500000  0.850000  45.262500   0.000000
# Ice       134.000000  1.550000  48.000000   0.500000
# Normal     71.727273  0.986364  50.086364   0.000000
# Poison     51.071429  1.221429  27.314286   0.000000
# Psychic    93.857143  1.371429  58.357143   0.142857
# Rock      113.333333  1.844444  87.611111   0.000000
# Water      85.928571  1.300000  57.967857   0.000000

# %%
group[["Height","Weight"]].mean()
# Out:
#             Height     Weight
# Type1
# Bug       0.900000  22.991667
# Dragon    2.666667  76.600000
# Electric  0.855556  31.788889
# Fairy     0.950000  23.750000
# Fighting  1.185714  54.285714
# Fire      1.216667  48.025000
# Ghost     1.466667  13.566667
# Grass     1.083333  27.991667
# Ground    0.850000  45.262500
# Ice       1.550000  48.000000
# Normal    0.986364  50.086364
# Poison    1.221429  27.314286
# Psychic   1.371429  58.357143
# Rock      1.844444  87.611111
# Water     1.300000  57.967857

# %%
group[["Height","Weight"]].min()
# Out:
#           Height  Weight
# Type1
# Bug          0.3     2.9
# Dragon       1.8     3.3
# Electric     0.3     6.0
# Fairy        0.6     7.5
# Fighting     0.5    19.5
# Fire         0.6     8.5
# Ghost        1.3     0.1
# Grass        0.4     2.5
# Ground       0.2     0.8
# Ice          1.4    40.6
# Normal       0.3     1.8
# Poison       0.4     1.0
# Psychic      0.9    19.5
# Rock         0.4     7.5
# Water        0.3     4.0

# %%
df
# Out:
#              No    Type1   Type2  Height  Weight  Legendary
# Name
# Bulbasaur     1    Grass  Poison     0.7     6.9          0
# Ivysaur       2    Grass  Poison     1.0    13.0          0
# Venusaur      3    Grass  Poison     2.0   100.0          0
# Charmander    4     Fire     NaN     0.6     8.5          0
# Charmeleon    5     Fire     NaN     1.1    19.0          0
# ...         ...      ...     ...     ...     ...        ...
# Moltres     146     Fire  Flying     2.0    60.0          1
# Dratini     147   Dragon     NaN     1.8     3.3          0
# Dragonair   148   Dragon     NaN     4.0    16.5          0
# Dragonite   149   Dragon  Flying     2.2   210.0          0
# Mewtwo      150  Psychic     NaN     2.0   122.0          1
#
# [150 rows x 6 columns]

# %%
#Drop irrelevant columns
df = df.drop(columns = ["Legendary", "No"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[88], line 2
#       1 #Drop irrelevant columns
# ----> 2 df = df.drop(columns = ["Legendary", "No"])
#
# File ~\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:5588, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5440 def drop(
#    5441     self,
#    5442     labels: IndexLabel | None = None,
#    (...)   5449     errors: IgnoreRaise = "raise",
#    5450 ) -> DataFrame | None:
#    5451     """
#    5452     Drop specified labels from rows or columns.
#    5453
#    (...)   5586             weight  1.0     0.8
#    5587     """
# -> 5588     return super().drop(
#    5589         labels=labels,
#    5590         axis=axis,
#    5591         index=index,
#    5592         columns=columns,
#    5593         level=level,
#    5594         inplace=inplace,
# ...

# %%
df1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[87], line 1
# ----> 1 df1
#
# NameError: name 'df1' is not defined

# %%
#Handle missing data
df = df.dropna(subset=["Type2"])  #dropna ---->>> drop not available values

# %%
df
# Out:
#                Type1   Type2  Height  Weight
# Name
# Bulbasaur      Grass  Poison     0.7     6.9
# Ivysaur        Grass  Poison     1.0    13.0
# Venusaur       Grass  Poison     2.0   100.0
# Charizard       Fire  Flying     1.7    90.5
# Butterfree       Bug  Flying     1.1    32.0
# ...              ...     ...     ...     ...
# Aerodactyl      Rock  Flying     1.8    59.0
# Articuno         Ice  Flying     1.7    55.4
# Zapdos      Electric  Flying     1.6    52.6
# Moltres         Fire  Flying     2.0    60.0
# Dragonite     Dragon  Flying     2.2   210.0
#
# [67 rows x 4 columns]

# %%
df.fillna({"Type2": "None"})
df
# Out:
#                Type1   Type2  Height  Weight
# Name
# Bulbasaur      Grass  Poison     0.7     6.9
# Ivysaur        Grass  Poison     1.0    13.0
# Venusaur       Grass  Poison     2.0   100.0
# Charizard       Fire  Flying     1.7    90.5
# Butterfree       Bug  Flying     1.1    32.0
# ...              ...     ...     ...     ...
# Aerodactyl      Rock  Flying     1.8    59.0
# Articuno         Ice  Flying     1.7    55.4
# Zapdos      Electric  Flying     1.6    52.6
# Moltres         Fire  Flying     2.0    60.0
# Dragonite     Dragon  Flying     2.2   210.0
#
# [67 rows x 4 columns]

# %%
df
# Out:
#                Type1   Type2  Height  Weight
# Name
# Bulbasaur      Grass  Poison     0.7     6.9
# Ivysaur        Grass  Poison     1.0    13.0
# Venusaur       Grass  Poison     2.0   100.0
# Charizard       Fire  Flying     1.7    90.5
# Butterfree       Bug  Flying     1.1    32.0
# ...              ...     ...     ...     ...
# Aerodactyl      Rock  Flying     1.8    59.0
# Articuno         Ice  Flying     1.7    55.4
# Zapdos      Electric  Flying     1.6    52.6
# Moltres         Fire  Flying     2.0    60.0
# Dragonite     Dragon  Flying     2.2   210.0
#
# [67 rows x 4 columns]
